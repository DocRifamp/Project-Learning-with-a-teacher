# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Алексей, привет!👋</b>
#
# Меня зовут Кирилл Васильев, мы уже встречались на проекте «Линейные модели». Рад снова быть ревьюером твоей работы!
#
# Я буду оставлять комментарии в твоем проекте. Пожалуйста, не удаляй их, они могут быть полезны в случае повторной проверки.
#
# Свои комментарии я буду обозначать <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным. Здесь же я могу давать советы и предложения.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# <br/>
# <div class="alert alert-info">
# Рекомендую для твоих комментариев использовать синий или любой другой цветной фон. Я постараюсь ничего не пропустить, но если комментарии будут выделены, то это мне очень поможет!
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-библиотек" data-toc-modified-id="Загрузка-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка библиотек</a></span></li><li><span><a href="#Первый-датасет-market_f" data-toc-modified-id="Первый-датасет-market_f-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Первый датасет market_f</a></span></li><li><span><a href="#Второй-датасет-market_m" data-toc-modified-id="Второй-датасет-market_m-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Второй датасет market_m</a></span></li><li><span><a href="#Третий-дасет-market_t" data-toc-modified-id="Третий-дасет-market_t-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Третий дасет market_t</a></span></li><li><span><a href="#Четвертый-датасет--money" data-toc-modified-id="Четвертый-датасет--money-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Четвертый датасет  money</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Предобрабока-market_f" data-toc-modified-id="Предобрабока-market_f-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Предобрабока market_f</a></span></li><li><span><a href="#Предобработка-market_m" data-toc-modified-id="Предобработка-market_m-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Предобработка market_m</a></span></li><li><span><a href="#Предобработка-market_t" data-toc-modified-id="Предобработка-market_t-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Предобработка market_t</a></span></li><li><span><a href="#Предобработка-money" data-toc-modified-id="Предобработка-money-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Предобработка money</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-market_f" data-toc-modified-id="Анализ-market_f-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Анализ market_f</a></span></li><li><span><a href="#Анализ-market_m" data-toc-modified-id="Анализ-market_m-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ market_m</a></span></li><li><span><a href="#Анализ-market_t" data-toc-modified-id="Анализ-market_t-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Анализ market_t</a></span></li><li><span><a href="#Анализ-money" data-toc-modified-id="Анализ-money-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Анализ money</a></span></li></ul></li><li><span><a href="#Объединение-таблиц" data-toc-modified-id="Объединение-таблиц-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Объединение таблиц</a></span></li><li><span><a href="#Корреляционный-анализ" data-toc-modified-id="Корреляционный-анализ-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Корреляционный анализ</a></span></li><li><span><a href="#Пайплайны-и-моделирование" data-toc-modified-id="Пайплайны-и-моделирование-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Пайплайны и моделирование</a></span><ul class="toc-item"><li><span><a href="#Тестовая-выборка-и-целевой-признак" data-toc-modified-id="Тестовая-выборка-и-целевой-признак-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Тестовая выборка и целевой признак</a></span></li><li><span><a href="#Определяем-признаки" data-toc-modified-id="Определяем-признаки-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Определяем признаки</a></span></li><li><span><a href="#Обработка-пропусков-+-кодирование" data-toc-modified-id="Обработка-пропусков-+-кодирование-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Обработка пропусков + кодирование</a></span></li><li><span><a href="#Пайплайн-подготовки--датасета" data-toc-modified-id="Пайплайн-подготовки--датасета-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Пайплайн подготовки  датасета</a></span></li><li><span><a href="#Итоговый-пайплайн" data-toc-modified-id="Итоговый-пайплайн-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Итоговый пайплайн</a></span></li><li><span><a href="#Подбор-и-настройка-с-RandomizedSearchCV" data-toc-modified-id="Подбор-и-настройка-с-RandomizedSearchCV-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Подбор и настройка с RandomizedSearchCV</a></span></li></ul></li><li><span><a href="#Анализ-важности-признаков" data-toc-modified-id="Анализ-важности-признаков-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Анализ важности признаков</a></span></li><li><span><a href="#Сегментация-покупателей" data-toc-modified-id="Сегментация-покупателей-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Сегментация покупателей</a></span></li><li><span><a href="#Общие-выводы" data-toc-modified-id="Общие-выводы-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Общие выводы</a></span></li><li><span><a href="#Дополнительный-анализ-сверх-задания" data-toc-modified-id="Дополнительный-анализ-сверх-задания-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Дополнительный анализ сверх задания</a></span></li></ul></div>

# %% [markdown]
# **Проект: Обучение с учителем**

# %% [markdown]
# **Описание:** «В один клик» осуществляет розничную торговлю посредством интернет-платформы, реализуя различные категории товаров.По результатам  анализа операционной деятельности за отчётный период выявлена негативная динамика ключевых показателей, характеризующих покупательскую активность целевой аудитории. Необходимо удержать постоянных клиентов, предлагая им товары по их вкусу.

# %% [markdown]
# **Задача:**  разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# Для реалиазции проекта предоставлено 4 дата сета. `market_file.csv` , `market_money.csv`, `market_time.csv`, `money.csv`.

# %% [markdown]
# Предварительный план работы следующий

# %% [markdown]
# 1.  Загрузка данных
# 2.  Предобработка данных
# 3.  Исследовательский анализ данных
# 4.  Объединение таблиц
# 5.  Корреляционный анализ
# 6.  Создание пайплайна для поиска оптимальной модели
# 7. Анализ важности признаков
# 8. Сегментация покупателей
# 9. Общие выводы

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Контекст и план проекта понятны.
#
# ***
#
# Я бы так расставил акценты:
#
# * в исследовательском анализе мы должны понять, чем отличаются активные клиенты от тех, чья активность снижается.
# * в результате построения модели мы должны перевести бинарные метки классов в вероятности, а также получить оценку важности признаков, что позволит уточнить выводы из исследовательского анализа.
# * ну и в итоге мы должны понять, какую группу-сегмент пользователей стоит удерживать в первую очередь и как именно.
#
# Это основанное на исследовании знание и позволит бизнесу максимизировать прибыль, качество и привлекательность сервиса.
# </div>

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# #### Загрузка библиотек

# %% [markdown]
# Загружаем необходимые библиотеки и датасеты.Сверяем содержимое предоставленных датасетов с тех.заданием

# %%
# Базовые библиотеки для работы с данными
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from typing import Dict
import re

# Статистический анализ
import phik

# sklearn: модели и предобработка
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import (
    StandardScaler,
    OneHotEncoder,
    OrdinalEncoder,
    MinMaxScaler,
    LabelEncoder
)
from sklearn.impute import SimpleImputer

# sklearn: модели
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# sklearn: валидация и метрики
from sklearn.model_selection import (
    train_test_split,
    RandomizedSearchCV,
    GridSearchCV
)
from sklearn.metrics import roc_auc_score, f1_score
from sklearn.dummy import DummyClassifier

# SHAP для интерпретации моделей
import shap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_31/1589166864.py in <module>
#       9
#      10 # Статистический анализ
# ---> 11 import phik
#      12
#      13 # sklearn: модели и предобработка
#
# ModuleNotFoundError: No module named 'phik'

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Для красоты можно объединить все `from sklearn.model_selection`

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Теперь все отлично.
# </div>

# %% [markdown]
# #### Первый датасет market_f

# %%
try:
    market_f = pd.read_csv('C:/Users/Алексей/Lessons_Python/datasets/market_file.csv',sep=",",decimal = '.', low_memory=False)
except:
     market_f= pd.read_csv("/datasets/market_file.csv",sep=",",decimal = '.', low_memory=False)

# %%
market_f.head()

# %% [markdown]
# #### Второй датасет market_m

# %%
try:
    market_m = pd.read_csv('C:/Users/Алексей/Lessons_Python/datasets/market_money.csv', sep=",",decimal = '.', low_memory=False)
except:
     market_m= pd.read_csv("/datasets/market_money.csv",sep=",",decimal = '.', low_memory=False)

# %%
market_m.head()

# %% [markdown]
# #### Третий дасет market_t

# %%
try:
    market_t = pd.read_csv('C:/Users/Алексей/Lessons_Python/datasets/market_time.csv', sep=",",decimal = ',', low_memory=False)
except:
     market_t = pd.read_csv("/datasets/market_time.csv",sep=",",decimal = ',', low_memory=False)

# %%
market_t.head()

# %% [markdown]
# #### Четвертый датасет  money

# %%
try:
    money = pd.read_csv('C:/Users/Алексей/Lessons_Python/datasets/money.csv', sep=";",decimal = ',', low_memory=False)
except:
     money= pd.read_csv("/datasets/money.csv",sep=";",decimal = ',', low_memory=False)

# %%
money.head()

# %% [markdown]
# **Промежуточный вывод**
#
# Данные загруженны в полном обьеме,соответствуют заявленному ТЗ

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично, что обрабатываешь случаи с запятой-разделителем.
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Создадим полезные функции для единобразной подготовки и анализа

# %%
# Функция анализа датасета
def dataframe_analysis(df, n_head=5, show_duplicates=True, show_missing=True):
    """
    Функция для комплексного анализа датафрейма
    
    Параметры:
    df (pd.DataFrame): входной датафрейм
    n_head (int): количество строк для отображения в head
    show_duplicates (bool): показывать информацию о дубликатах
    show_missing (bool): показывать информацию о пропущенных значениях
    """
    print("\n--- Общая информация о датафрейме ---")
    print(f"Форма датафрейма: {df.shape[0]} строк, {df.shape[1]} столбцов")
    print(f"Размер датафрейма в памяти: {round(df.memory_usage().sum() / 1024**2, 2)} МБ")
    
    print("\n--- Первые строки датафрейма ---")
    display(df.head(n_head))
    
    print("\n--- Основная статистика ---")
    display(df.describe(include='all'))
    
    print("\n--- Подробная информация ---")
    print(df.info())
    
    if show_missing:
        print("\n--- Пропущенные значения ---")
        missing = df.isnull().sum()
        if missing.any():
            print(missing[missing > 0])
        else:
            print("Пропущенных значений нет")
    
    if show_duplicates:
        print("\n--- Дубликаты ---")
        duplicates = df.duplicated().sum()
        if duplicates > 0:
            print(f"Найдено {duplicates} дубликатов")
            display(df[df.duplicated(keep=False)].head())
        else:
            print("Дубликатов не обнаружено")
            
    print("\n--- Типы данных столбцов ---")
    display(df.dtypes)
    
    print("\n--- Уникальные значения в каждом столбце ---")
    for col in df.columns:
        print(f"\nУникальные значения в столбце '{col}': {df[col].nunique()}")
         
    print("\n--- Детальный анализ уникальных значений для нечисловых столбцов ---")
    non_numeric_cols = df.select_dtypes(exclude=['number']).columns
    
    for col in non_numeric_cols:
        unique_values = df[col].unique()
        print(f"\nУникальные значения в столбце '{col}':")
        print(f"Количество уникальных значений: {len(unique_values)}")
        print(f"Сами значения: {unique_values}\n")
        
    
        if len(unique_values) > 5:
            print(f"Первые 5 уникальных значений для примера: {unique_values[:5]}")
        else:
            print("Все уникальные значения показаны выше")

# %%
# Для  переименования столбцов
def normalize_string(text: str) -> str:
    if pd.isna(text) or text is None:
        return 'none'
    
    text = str(text).lower().strip()
    text = re.sub(r'[^a-za-я0-9_]', '_', text)
    text = re.sub(r'_+', '_', text)  
    text = text.strip('_')  
    

    return text

def rename_columns(df: pd.DataFrame) -> (pd.DataFrame, Dict):
    original_columns = df.columns.tolist()
    new_columns = [normalize_string(col) for col in original_columns]  
    
    rename_log = {
        original: new for original, new in zip(original_columns, new_columns)
        if original != new
    }
    
    if rename_log:
        print("Изменения в названиях столбцов:")
        for original, new in rename_log.items():
            print(f" {original} → {new}")
    
    df.columns = new_columns
    return df, rename_log

# %%
# Для нормализации текста ячеек
def standardize_text(series):
    if pd.api.types.is_string_dtype(series):
        try:
            return series.str.replace(' ', '_').str.lower().str.strip()
        except Exception as e:
            print(f"Ошибка при обработке : {e}")
            return series
    return series

# %% [markdown]
# #### Предобрабока market_f

# %%
dataframe_analysis(market_f)

# %% [markdown]
# На данном этапе на себя обращют внимание и требуют исправелния названия стоблцов и наличие неявных дубликатов в `Тип сервиса`  'стандартт' 'стандарт'

# %%
rename_columns(market_f)

# %%
# теперь тектс в колонках
text_columns= ['покупательская_активность','тип_сервиса','популярная_категория']
market_f[text_columns] = market_f[text_columns].apply(standardize_text)

# %%
 # Создаем словарь для ручной коррекции
correction_dict = {
        'тип_сервиса': {
            'стандартт': 'стандарт',     
        }
    }
for col, corrections in correction_dict.items():
        market_f[col] = market_f[col].replace(corrections)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍  Точно

# %% [markdown]
# #### Предобработка market_m

# %%
dataframe_analysis(market_m)

# %% [markdown]
# на себя обращют внимание и требуют исправелния названия стоблцов и использования термина препредыдущий_месяц

# %%
rename_columns(market_m)

# %%
# теперь тектс в колонках
text_columns= ['период']
market_m[text_columns] = market_m[text_columns].apply(standardize_text)

# %%
# Создаем словарь для ручной коррекции
correction_dict = {
        'период': {
            'препредыдущий_месяц': 'месяц_до_предыдущего',     
        }
    }
for col, corrections in correction_dict.items():
        market_m[col] = market_m[col].replace(corrections)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Согласен, так понятнее.

# %%
dataframe_analysis(market_m)

# %% [markdown]
# #### Предобработка market_t

# %%
dataframe_analysis(market_t)

# %% [markdown]
# на себя обращют внимание и требуют исправелния названия стоблцов и использования термина предыдцщий

# %%
rename_columns(market_t)

# %%
# теперь тектс в колонках
text_columns= ['период']
market_m[text_columns] = market_m[text_columns].apply(standardize_text)

# %%
# Создаем словарь для ручной коррекции
correction_dict = {
        'период': {
            'предыдцщий_месяц': 'предыдущий_месяц',     
        }
    }
for col, corrections in correction_dict.items():
        market_t[col] = market_t[col].replace(corrections)

# %% [markdown]
# #### Предобработка money

# %%
dataframe_analysis(money)

# %% [markdown]
# на себя обращют внимание и требуют исправления названия стоблцов

# %%
rename_columns(money)

# %% [markdown]
# **Предварительный вывод**
#
# Произведено переименование столбцов под единый формат и исправленние замеченных опечаток в значениях
#
# `market_f`
#
# На данном этапе на себя обращют внимание и требуют исправелния названия стоблцов и наличие неявных дубликатов в `Тип сервиса`  'стандартт' 'стандарт'
#
# `market_m`
#
# Исправлены названия столбцов и  термин `препредыдущий_месяц`
#
# `market_t`
#
# Исправлены названия столбцов и  термина `предыдцщий`
#
# `money`
#
# Исправлены названия столбцов
#
#
# Дубликатов не выявлено. 1 неявный дубликат исправлен

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 У нас данные внутренней аналитики, они действительно чаще бывают относительно чистыми. Дадасет качественный
#
# По предобработке все ок.
#
# </div>

# %% [markdown]
# ### Исследовательский анализ данных

# %%
def viz_num_variable(df, column, title):
    sns.set(rc={"figure.figsize": (15, 5)})

    fig,axes=plt.subplots(1,2)

    sns.histplot(data=df[column], bins=20, ax=axes[0])
    axes[0].set(ylabel='Кол-во покупателей', xlabel=column)

    sns.boxplot(data=df[column], ax=axes[1])
    axes[1].set(ylabel=column)

    plt.suptitle(title)
    plt.show()

# %%
def plot_categorical_distribution(
    df: pd.DataFrame,
    column_name: str,
    figsize: tuple = (8, 6),
    title: str = None,
    orientation: str = 'y'  
) -> None:
    """
    Визуализация распределения категориального признака.
    
    Параметры:
    - df: DataFrame с данными
    - column_name: название столбца для визуализации
    - figsize: размер фигуры (ширина, высота)
    - title: заголовок графика
    - orientation: ориентация графика ('y' или 'x')
    """
    # Создаем фигуру
    plt.figure(figsize=figsize)
    
    # Определяем порядок отображения категорий
    order = df[column_name].value_counts().index
    
    # Создаем график
    if orientation == 'y':
        sns.countplot(y=df[column_name], order=order)
    elif orientation == 'x':
        sns.countplot(x=df[column_name], order=order)
    else:
        raise ValueError("orientation должен быть 'y' или 'x'")
    
    # Устанавливаем заголовок
    if title is None:
        title = f'Распределение по {column_name}'
    plt.title(title)
    plt.show()

# %% [markdown]
# #### Анализ market_f

# %%
market_f.describe()

# %%
# Получаем список числовых столбцов
numeric_columns = market_f.select_dtypes(include=['float64', 'int64']).columns

# и по каждому числовому столбцу
try:
    for column in numeric_columns:
        if market_f[column].notna().sum() > 0:  
            title = f'Анализ показателя: {column}'
            viz_num_variable(market_f, column, title)
        else:
            print(f"Пропущен столбец {column} - нет данных")
except Exception as e:
    print(f"Ошибка при визуализации: {str(e)}")

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Важно прокомментировать графики

# %%
# Список столбцов для визуализации
columns = [
    'покупательская_активность',
    'тип_сервиса',
    'разрешить_сообщать',
    'популярная_категория'
]

# Общие параметры визуализации
base_figsize = (8, 6)

for column in columns:
    
    title = f'Распределение по {column.replace("_", " ").title()}'
    
    plot_categorical_distribution(
        df=market_f,
        column_name=column,
        figsize=base_figsize,
        title=title
    )

# %% [markdown]
# **выводы по market_f** :
#
# Показатель `маркет_актив_6_мес` отмечаются выбивающиеся значения около нулевых значений. Для наибольшего количества покупателей составляет 4.2. Распределение стремится к нормальному.
#
# Показатель `маркет_актив_тек_мес` дискретен максимальное значение составило 5 минимальное 3.
#
# В столбце `длительность` среднее значение составила 606 дней.
#
# Показатель `акционные покупки` представлен двумя пиками до 270 и до 70 покупателей
# второй пик вероятно можно трактовать как выброс однако в настоящее время ничего делать с ним не будем.
#
# Средний просмотр за категорий за `визит`  дискретен представлен в диапазоне от 1 до 6
#
# `Неоплаченные продукты`, `Ошибка сервиса`  так же дискретны представлены в диапазоне от 0 до 10 и от 0 до 9 соответственно
#
# Гистограмма анализа `страниц за визит` наиболее стремится к нормальному распределению по сравнению с остальными графиками выбросов не отмечено.
#
# Показатель `Покупательская активность` представлен 2  значениями прежний уровень и снизилась значение снизилась почти в 2 ое меньше прежнего уровня.
#
# По `типам сервиса` клиенты распределены не равномерно стандартных клиентов значительно больше
#
# Так же большинство клиентов предоставили свою данные для обработки.
#
# Самой популярной категорией среди товаров стали `товары для детей`.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# По акционным нельзя назвать такую большую группу «выбросом». Здесь можно заметить, что если бы доступ к акциям у всех клиентов был бы одинаковым, то здесь ожидали бы увидеть нормальное или близкое к нему распределение. Если наблюдаем две модельности, можем предположить, что были какие-то специальные предложения для некоторых клиентов.

# %% [markdown]
# #### Анализ market_m

# %%
market_m.describe()

# %%
result = market_m.query('выручка == 106862.2')
display(result)

# %%
market_m = market_m.drop(market_m[market_m['выручка'] == 106862.2].index)

# %% [markdown]
# В данных отмечается единчный выброс в 106к что в целом и может быть реальным случаем однако для последующего моделирования
# может помешать.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Абсолютно верно. Такой выброс точно помешает моделям и не особо поможет аналитике. Нужно его обработать.

# %% [markdown]
# так же согласно заданию  необходимо отобрать клиентов с покупательской активностью не менее трех месяцев. Следоавтельно необходимо удалить клиентов не принесших за это время выручки

# %%
result = market_m.query('выручка == 0.000000')
display(result)

# %%
market_m = market_m.drop(market_m[market_m['выручка'] == 0.0].index)
market_m = market_m.reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍

# %%
viz_num_variable(market_m, 'выручка', 'Анализ показателя: выручка' )

# %% [markdown]
# Так же необходимо удалить клиентов с  нулевой выручкой из остальных датафреймов

# %%
bad_clients= [215348,215357, 215359]
market_f = market_f[~market_f['id'].isin(bad_clients)].reset_index(drop=True)
market_t = market_t[~market_t['id'].isin(bad_clients)].reset_index(drop=True)

# %% [markdown]
# **выводы по анализу market_m** :
#
# Удален выброс единственное значение в 106862.
# Так же удалены клиенты не принесших выручки для предстоящего моделирования они не отвечают заданным требованиям.
# Сразу же эти клиенты удалены из остальных предоставленных дата сетов во избежание дальнейших ошибок.
# Данные представлены гистограммой образующий правильный купол нормального распределения.

# %% [markdown]
# #### Анализ market_t

# %%
market_t.describe()

# %%
viz_num_variable(market_t, 'минут', 'Анализ показателя: минуты' )

# %% [markdown]
# **Выводы по анализу market_t** :
#
# Данные представлены почти правильны куполом нормального распределения однако с 2 мя пиками около  12 и 15 минутам. Среднее значение составило 13.3.

# %% [markdown]
# #### Анализ money

# %%
money.describe()

# %%
viz_num_variable(money, 'прибыль', 'Анализ показателя: прибыль' )

# %% [markdown]
# **Выводы по анализу money** :
# Данные представлены почти правильны куполом нормального распределения 1 пиком около  4 пунктов. Среднее значение составило 4.04.

# %% [markdown]
# **Промежуточный анализ**
#
# **по market_f**
#
# Показатель маркет_актив_6_мес отмечаются выбивающиеся значения около нулевых значений. Для наибольшего количества покупателей составляет 4.2. Распределение стремится к нормальному.
#
# Показатель маркет_актив_тек_мес дискретен максимальное значение составило 5 минимальное 3.
#
# В столбце длительность среднее значение составила 606 дней.
#
# Показатель акционные покупки представлен двумя пиками до 270 и до 70 покупателей
# второй пик вероятно можно трактовать как выброс однако в настоящее время ничего делать с ним не будем.
#
# Средний просмотр за категорий за визит  дискретен представлен в диапазоне от 1 до 6
#
# Неоплаченные продукты, Ошибка сервиса  так же дискретны представлены в диапазоне от 0 до 10 и от 0 до 9 соответственно
#
# Гистограмма анализа страниц за визит наиболее стремится к нормальному распределению по сравнению с остальными графиками выбросов не отмечено.
#
# Показатель Покупательская активность представлен 2  значениями прежний уровень и снизилась значение снизилась почти в 2 ое меньше прежнего уровня.
#
# По типам сервиса клиенты распределены не равномерно стандартных клиентов значительно больше
#
# Так же большинство клиентов предоставили свою данные для обработки.
#
# Самой популярной категорией среди товаров стали товары для детей.
#
# **по market_m** :
#
# Удален выброс единственное значение в 106862.
# Так же удалены клиенты не принесших выручки для предстоящего моделирования они не отвечают заданным требованиям.
# Сразу же эти клиенты удалены из остальных предоставленных дата сетов во избежание дальнейших ошибок.
# Данные представлены гистограммой образующий правильный купол нормального распределения.
#
# **по  market_t** :
#
# Данные представлены почти правильны куполом нормального распределения однако с 2 мя пиками около 12 и 15 минутам. Среднее значение составило 13.3.
#
#
# Суммарно данные представелнны в полном обьеме соответсвующего качества. Удален едиственный выброс. Часть данных соотвествует нормальному распределению.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Здесь также можно уточниться по акционным покупкам.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Исследовательский анализ мы делаем для того, чтобы понять, какие закономерности заложены в наших данных. Здесь важно посмотреть на распределения признаков в разрезе целевого признака (снижения активности).
#
# Можно построить и наложить друг на друга гистограммы по данным в подвыборках с и без снижения активности. Можно расположить рядом два боксплота, для категориальных данных − две диаграммы.
#
# Проще всего наложить гистограммы в контексте таргета, добавив в код гистограмм параметр hue='таргет'.
#
# Думаю, так мы увидим гораздо больше интересной информации. Она нам особенно пригодится для части с исследованием сегмента покупателей.
#
# ***
#
# По итогам исследовательского анализа  у нас должен быть вывод с портретом покупателя, который снижает активность: какие значения каких признаков для него будут характерны. Сколько страниц он в среднем просматривает, больше или меньше это, чем у активных пользователей, также с акционными покупками, временем на сайте и другими признаками.
#
# Фактически основной костяк выводов проекта делаем уже здесь. Модель нам нужна для перевода категориального признака (факт снижения активности) в вероятностный (вероятность снижения), чтобы дальше чуть более пластично исследовать выбранный сегмент.
#
#
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# Согласно Вашему замечнию вынес анализ по подвыборкам отдельно.После кода написал расшиенныве вводы по получившимся результатам
# </div>

# %%
# Настройка стиля графиков
sns.set(style="whitegrid")
plt.figure(figsize=(16, 20))

# Cетка для графиков
fig, axes = plt.subplots(4, 3, figsize=(20, 20))
plt.tight_layout(pad=3.0)

# Числовые признаки с наложенными гистограммами
numeric_features = ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 
                   'длительность', 'акционные_покупки',
                   'средний_просмотр_категорий_за_визит',
                   'неоплаченные_продукты_штук_квартал',
                   'ошибка_сервиса', 'страниц_за_визит']


# название целевого столбца
target_column = 'покупательская_активность'

for i, feature in enumerate(numeric_features):
    row = i // 3
    col = i % 3
    sns.histplot(
        ax=axes[row, col], 
        data=market_f, 
        x=feature, 
        hue=target_column,  
        multiple='stack', 
        kde=True,
        alpha=0.6
    )
    axes[row, col].set_title(f'Распределение {feature}')

# Категориальные признаки
categorical_features = ['тип_сервиса', 'разрешить_сообщать', 'популярная_категория']

for i, feature in enumerate(categorical_features):
    row = (i + len(numeric_features)) // 3
    col = (i + len(numeric_features)) % 3
    sns.countplot(
        ax=axes[row, col], 
        data=market_f, 
        x=feature, 
        hue=target_column  
    )
    axes[row, col].set_title(f'Распределение {feature}')
    plt.setp(axes[row, col].get_xticklabels(), rotation=45, ha='right')

plt.show()

# %%
plt.figure(figsize=(16, 12))

for i, feature in enumerate(numeric_features):
    plt.subplot(3, 3, i+1)
    sns.boxplot(
        x=target_column,  
        y=feature, 
        data=market_f
    )
    plt.title(f'Boxplot {feature}')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Замечательно по визуализации.
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
#
# Характерные признаки:
#  1. Маркет_актив_6_мес и маркет_актив_тек_мес
#  - У покупателей с падением активности значения маркетинговой активности в последние месяцы ниже.
#  - На графиках видно, что их распределение сдвинуто влево по сравнению с «остались активны».
#  2. Длительность (время на сайте)
#  - У менее активных покупателей время на сайте в среднем меньше.
#  - Активные сидят дольше (пик распределения выше).
#  3. Акционные покупки
#  - Снижающие активность чаще покупают по акциям (распределение чуть смещено вправо).
#  - То есть они более чувствительны к скидкам.
#  4. Средний расход по категориям за визит
#  - Ушедшие в спад тратят в среднем меньше на визит.
#  - У активных распределение смещено вправо — они покупают дороже.
#  5. Непопулярные продукты, штук за квартал
#  - Снижающие активность покупают меньше уникальных/редких товаров.
#  - Активные больше экспериментируют.
#  6. Ошибки сервиса
#  - У менее активных пользователей чаще встречаются ошибки (распределение смещено вправо). Это могло повлиять на отток.
#  7. Страниц за визит
#  - У «снижающих активность» в среднем около 6–7 страниц за визит,
#  - тогда как у активных — около 10–12 страниц а значит, они меньше исследуют сайт.
#  8. Разрешить сообщения
#  - Те, кто снизил активность, чаще отказываются от сообщений.
#  - Активные чаще соглашаются.
#  9. Популярные категории
#  - Менее активные сильнее сосредоточены на 2–3 категориях (меньше разнообразия).
#  - У активных покупки распределены более равномерно.
#
# Исходя из сделнных выводов офрмим портрет покупателя с падением активности:
#
# Это клиент, который проводит меньше времени на сайте, смотрит меньше страниц, чаще реагирует на акции, но покупает дешевле и в узком наборе категорий. Он хуже вовлекается, не готов получать уведомления и чаще сталкивается с ошибками сервиса.
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Отлично, что делаешь краткое резюме, все верно по портрету.
# </div>

# %% [markdown]
# ### Объединение таблиц

# %%
market_m = pd.pivot_table(data=market_m, index='id', columns='период', values='выручка')

# %%
market_m.columns = ['выручка_предыдущий_месяц', 'выручка_месяц_до_предыдущего', 'выручка_текущий_месяц']

# %%
market_t = pd.pivot_table(data=market_t, index='id', columns='период', values='минут')

# %%
market_t.columns = ['время_предыдущий_месяц', 'время_текущий_месяц']

# %%
market_f = market_f.set_index('id')

# %%
market = market_f.merge(market_m, on='id').merge(market_t, on='id')

# %%
dataframe_analysis(market)

# %%
missing_values = market[market['выручка_текущий_месяц'].isnull()]
display(missing_values)

# %%
market['выручка_текущий_месяц'].fillna(market['выручка_текущий_месяц'].median(), inplace=True)

# %% [markdown]
# **Промежуточный вывод** : Таблицы успешно обьеденины

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Все замечательно и оптимально.

# %% [markdown]
# ### Корреляционный анализ

# %%
# Определяем количественные признаки
quantitative_cols = [
     'маркет_актив_6_мес',
     'маркет_актив_тек_мес',
     'длительность',
     'акционные_покупки',
     'средний_просмотр_категорий_за_визит', 
     'неоплаченные_продукты_штук_квартал',     
     'ошибка_сервиса',                      
     'страниц_за_визит',
     'выручка_предыдущий_месяц',             
     'выручка_месяц_до_предыдущего',         
     'выручка_текущий_месяц',                
     'время_предыдущий_месяц',                
     'время_текущий_месяц'                  
    
]

# Определяем категориальные признаки
categorical_cols = [
    'покупательская_активность',            
    'тип_сервиса',                           
    'разрешить_сообщать',                    
    'популярная_категория',
]

# Объединяем все признаки для анализа
all_cols = quantitative_cols + categorical_cols

# Вычисляем матрицу корреляций с помощью Phik
corr_phik = market[all_cols].phik_matrix(
    interval_cols=quantitative_cols
)

# Создаем тепловую карту
plt.figure(figsize=(14, 10))
sns.heatmap(
    corr_phik, 
    annot=True, 
    cmap='coolwarm', 
    fmt=".2f", 
    linewidths=0.5,
    vmin=0,  
    vmax=1   
)

plt.title('Матрица корреляций Phik между всеми признаками', fontsize=14)
plt.xticks(rotation=45, ha='right')  
plt.yticks(rotation=0)  
plt.tight_layout()  
plt.show()

# %%
# Парная корреляция между ключевыми показателями
sns.pairplot(market[quantitative_cols + ['покупательская_активность']], hue='покупательская_активность', diag_kind='kde')
plt.suptitle('Парная корреляция показателей', y=1.02)
plt.show()

# %% [markdown]
# **промежуточный вывод**
#
# На основании проведенного анализа выявлены следующие статистические зависимости:
#
# Сильная корреляционная связь установлена между следующими показателями:
#
# Значения выручки за  месяц до предыдущего демонстрируют высокую степень зависимости от показателей выручки за предыдущий месяц
#
# Существует значимая корреляция между покупатльской активностью и кол-вом страниц за визит а так же время за предыдущий месяц

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Все так, при этом супер-большой корреляции нет, будем считать, что мультиколлинеарности нет, ничего обрабатывать дополнительно не нужно.

# %% [markdown]
# ### Пайплайны и моделирование

# %% [markdown]
# #### Тестовая выборка и целевой признак

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.25

X_train, X_test, y_train, y_test = train_test_split(
    market.drop(['покупательская_активность'], axis=1),
    market['покупательская_активность'],
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = market['покупательская_активность']) # сохранем пропорции классов в целевой переменной

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train) # кодируем целевые значения для обучения
y_test = label_encoder.transform(y_test) # кодируем целевые значения для тестирования

# %% [markdown]
# #### Определяем признаки

# %%
ohe_columns = ['популярная_категория'] # признак, который будет преобразован в бинарные колонки
ord_columns = ['тип_сервиса',
               'разрешить_сообщать'
              ]  # признаки с естественным порядком или иерархией
num_columns = [
 'маркет_актив_тек_мес',
 'длительность',
 'акционные_покупки',
 'средний_просмотр_категорий_за_визит',
 'неоплаченные_продукты_штук_квартал',
 'ошибка_сервиса',
 'страниц_за_визит',
 'выручка_предыдущий_месяц',
 'выручка_месяц_до_предыдущего',
 'выручка_текущий_месяц',
 'время_предыдущий_месяц',
 'время_текущий_месяц'
    ]   # количественные показатели

# %% [markdown]
# ####  Обработка пропусков + кодирование

# %%
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore',  sparse_output=False))
    ]
    )

# %%
# SimpleImputer + ORD
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['стандарт', 'премиум'],
                    ['да', 'нет']], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %% [markdown]
# #### Пайплайн подготовки  датасета

# %%
data_preprocessor = ColumnTransformer(
    transformers=[
        ('ohe', OneHotEncoder(handle_unknown='ignore'), ohe_columns),
        ('ord', OrdinalEncoder(), ord_columns),
        ('num', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', MinMaxScaler())
        ]), num_columns)
    ],
    remainder='passthrough'
)

# %% [markdown]
# #### Итоговый пайплайн

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %%
pipe_final.fit(X_train, y_train)

y_test_pred = pipe_final.predict_proba(X_test)[:,1]
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred)}')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично, что используешь `remainder='passthrough'` . Хороший выбор гиперпараметров и значений для подбора. Отлично, что пробуем два типа масштабирования.
# </div>

# %% [markdown]
# Получена первичная модель.Далее с помощью RandomizedSearchCV осуществим подбор оптимальных гипер параметров и модели

# %% [markdown]
# #### Подбор и настройка с RandomizedSearchCV

# %%
param_grid = [
    # словарь для DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для  KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },
   # словарь для LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    # словарь модели SVC()
    {
        'models': [SVC(random_state=RANDOM_STATE, kernel='poly', probability=True)],
        'models__degree': range(2, 3),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }

]

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search.fit(X_train, y_train)

# %%
print ('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В тренажере была неточность. Строго говоря, выше выводишь качество не на тренировочной выборке (это когда на чем обучились, на том и предсказали), а на кросс-валидации. Внутри кросс-валидации у нас есть разделение на сплиты, часть из них (тренировочный сплит) участвует в обучении, тестовый (или валидационный) - в обучении не участвует, на нем мы оцениваем качество и подбираем гиперпараметры. Это все скрыто от нас внутри функции, но в итоге мы получаем некоторую приближенную к объективной оценку.
#
# Если же обучить модель на тренировочной выборке, а затем на ней же предсказать качество, то оно будет близко к 100%. Иногда такую оценку на тренировочной выборке используют для того, чтобы проверить, что модель вообще обучается.
#
# </div>

# %%
# Обучаем DummyClassifier на тренировочной выборке
dummy_clf = DummyClassifier(strategy='most_frequent') 
dummy_clf.fit(X_train, y_train)

# Получаем предсказания для тестовой выборки
y_dummy_pred = dummy_clf.predict(X_test)
y_dummy_prob = dummy_clf.predict_proba(X_test)[:, 1]  # Если используем 'mean', то это будет просто среднее

# Вычисляем ROC-AUC для константной модели
dummy_roc_auc = roc_auc_score(y_test, y_dummy_prob)
print(f'ROC-AUC для константной модели: {dummy_roc_auc}')

# Теперь сравниваем с  лучшей моделью
best_model = randomized_search.best_estimator_  
y_best_pred = best_model.predict(X_test)
y_best_prob = best_model.predict_proba(X_test)[:, 1]

# Вычисляем ROC-AUC для лучшей модели
best_roc_auc = roc_auc_score(y_test, y_best_prob)
print(f'ROC-AUC для лучшей модели: {best_roc_auc}')

# Сравниваем результаты
if best_roc_auc > dummy_roc_auc:
    print("Лучшая модель значительно лучше константной модели.")
else:
    print("Лучшая модель не показала значительного улучшения по сравнению с константной моделью.")

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# ROC-AUC для константной модели по определению всегда будет 0.5. Кажется, специально замерять его нет смысла.
#
#
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# Хм а ведь дейстительно а зачем же это вообще придумано?
# <div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Что придумано? Константная модель. Ну для остальных метрик она уже будет иметь смысл.
#
# Точно также не будет иметь смысла, например, подбирать идеальный порог классов для максимизации F1-меры. Метрика будет средним гармоническим и по определению идеальный порог для нее будет 0.5 Но иногда студенты Практикума реализуют подбор порога.
#
# В случае accuracy константную модель можем посчитать как долю частого класса (тоже вытекает из формулы метрики). Если качество нашей модели не сильно выше, значит «доля объясненной дисперсии или энтропии» будет незначительной ,смысла от модели не будет.
#
# Можем вспомнить здесь значение метрики R2 - это как раз отношение MSE нашей модели к MSE константной модели (предсказанием средним). Вот метрика как раз показывает, насколько наша модель лучше случайной. Очень полезное знание.
#
# Всегда можем посчитать то же самое «руками», без реализованной метрики − сравниваем, смотрим, смогла ли модель объяснить данные.
# </div>

# %%
grid = GridSearchCV(
    pipe_final, 
    param_grid=param_grid, 
    cv=5, 
    scoring='roc_auc', 
    n_jobs=-1
)

#обучение модели на тренировочной выборке
grid.fit(X_train, y_train)

#вывод лучшей модели
print('Лучшая модель и её параметры:', grid.best_estimator_)
print ('Метрика лучшей модели:', grid.best_score_)

# %%
# Получаем вероятности для положительного класса
y_test_prob = randomized_search.predict_proba(X_test)[:, 1]

# Вычисляем метрику ROC-AUC
roc_auc = roc_auc_score(y_test, y_test_prob)
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc}')

# %% [markdown]
# **Промежуточные выводы**
#
# В рамках поставеленной задачи подобрана модель для прогнозирования метрика ROC-AUC на тестовой выборке составило  0.92
#
# Метрика на тренировочной выборке: 0.89
#
# Разница в метриках говорит о том, что:
#
# - Модель хорошо обобщает данные
#
# - Нет явного переобучения
#
# - Модель даже немного лучше работает на тестовых данных

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
# По заданию проекта здесь важно аргументировать выбор метрики качества. Почему используем именно ROC_AUC?

# %% [markdown]
# <br/>
# <div class="alert alert-info">
#
# ROC AUC (Receiver Operating Characteristic Area Under the Curve) — это метрика, которая помогает оценить качество классификационных моделей. Она показывает, насколько хорошо модель может различать два класса. ROC AUC рассчитывается как площадь под кривой ошибок, где по оси X откладывается доля ложных положительных результатов (FPR), а по оси Y — доля истинных положительных результатов (TPR).
#
# Основные характеристики ROC AUC:
#
# Значения ROC AUC варьируются от 0 до 1.
#
# Значение 1 указывает на идеальную модель, которая правильно классифицирует все объекты.
#
# Значение 0,5 означает, что модель работает не лучше случайного выбора.
#
# Значение меньше 0,5 говорит о том, что модель предсказывает противоположные значения.
#
# а следовательно ROC AUC особенно полезна в задачах бинарной классификации, где модель должна определить, к какому из двух классов относится объект.В нашем случае это определение уровня покупательской активности (снизилась/осталась прежней).соответсвенно данная метрика подходит для наших задач
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Конркетно в нашей задаче нам важно лишь то, что эта метрика учитывает и полноту, и точность комплексно, а не по отдельности.
#
# Дисбаланс классов у нас небольшой, порог нам подбирать не нужно, поэтому в целом подошли бы все комплексные метрики : f1, accuracy, ROC_AUC
# </div>

# %% [markdown]
# ### Анализ важности признаков

# %%
X_train_2 = pipe_final.named_steps['preprocessor'].fit_transform(X_train)
explainer = shap.LinearExplainer(randomized_search.best_estimator_.named_steps['models'], X_train_2)

X_test_2 = pipe_final.named_steps['preprocessor'].transform(X_test)

feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()

X_test_2 = pd.DataFrame(X_test_2, columns=feature_names)
 
shap_values = explainer(X_test_2)
 
display(shap.plots.bar(shap_values, max_display=30))
shap.plots.beeswarm(shap_values, max_display=15)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Все так.

# %% [markdown]
# **Промежуточный вывод**
#
# Согласно плану методом SHAP (SHapley Additive exPlanations) выполнена оценка вклада признака. В ТОП 3 лучших вошли следуюющие параметры `средний_просмотр_категорий_за _визит` , `страниц_за_визит`, `время_предыдущий месяц`.
# а вот самыми худшими признаками стали `популярная_категория_товары_для детей`,`популярная_категрия_кухонная_посуда`,`популярная_категория`.
#
# Весьма вероятно что время проведенное на сайте оказывает значительное влияиние на покупательскую активность, хотя стоит помнить что тот кто собствено покупает что либо будет задерживаться на сайте дольше(оформлять заказ заполняить данные о карте и тд и тп) чем следует на принятие решения о покупке.Возможно данный топ 3 на самом деле своего рода засветкой данных..Необходимо уточнить у зазчика особенности сбора данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Все так. Здесь стоит различать причинность и корреляцию.
#
# Количество времени, проводимое на сайте − это просто индикатор заинтересованности в покупках, но не причина активности в покупках. Примерно как значок недостатка топлива в баке не является причиной остановки автомобиля, хотя и коррелирует с фактом остановки.

# %% [markdown]
# ### Сегментация покупателей

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В самом начале было бы логично прописать, како сегмент и почему мы выбрали для анализа.
#
# Логика может быть следующей: выше мы исследовали, чем активные клиенты различаются с клиентами, чья активность снижается. Проанализировали все закономерности итд, а здесь мы на основе анализа выбираем группу, активность которой нам выгоднее удерживать в первую очередь. Или группу, исследование которой может уточнить наши выводы о данных.

# %% [markdown]
# <br/>
# <div class="alert alert-info">
#
# ну надо отдать должное я на этом этапе еще не очень понимал что будет дальше и как я буду делать задание дальше.(готовить супер вычищенные проект и подчищать повествование задним числом  мне кажется не очень честным. тогда он небудет отражать ход моих мыслей) если что  я готов переделать))
#  <div >

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Кажется, что если мы выше в исследовательском анализе все просмотрели, то здесь уже выбор сегмента должен вырисовываться.
#
# В твоем прошлом решении анализа в разрезе таргета не было, тогда ты совершенно логично сделал некоторый разведочный анализ здесь.
#
# В теперяшнем виде я бы скорее сразу начал шаг сегментации с аргументации выбора сегмента. Кажется, с точки зрения презентации работы это будет лучше.
#
# Но я полностью понимаю твою логику, думаю, что и твое решение выглядит вполне гармонично.

# %% [markdown]
# Добавляем  к данным покупателей их  вероятность отношения к классу сниженный уровень активности

# %%
y_pred = grid.predict_proba(X_test)
X_test['вероятность'] = y_pred[:, 1]
data = X_test.sort_values(by='вероятность')
data.head()

# %%
segment_data = data.merge(money, on ='id')

# %%
segment_data.head()

# %% [markdown]
# Рассмотрим взаимоотношения прибыли к вероятности снижнения активности

# %%
fig = plt.figure(figsize=(10,8))
sns.scatterplot(data=segment_data, y='прибыль', x='вероятность')
plt.xlabel('Вероятность снижения активности')
plt.ylabel('Прибыль')
plt.title('Зависимость вероятности снижения активности от выручки')
plt.show()

# %% [markdown]
# Ярких зависимостей не выявлено.Продолжим анализ со следующими признаками

# %%
def build_scatterplots(cat_columns):
    for cat_col in cat_columns:
        fig = plt.figure(figsize=(10,8))
        sns.scatterplot(data=segment_data, y='прибыль', x='вероятность', hue=cat_col)
        plt.xlabel('Вероятность снижения активности')
        plt.ylabel('Прибыль')
        plt.title('Зависимость вероятности снижения активности от выручки')
        plt.show()

# %%
cat_columns = list(segment_data.select_dtypes(include='object').columns)
build_scatterplots(cat_columns)

# %%
def histogram(df, col, target, rotation_angle=45):
    plt.figure(figsize=(8,6))
    plot = sns.histplot(
        df, 
        bins=20, 
        kde=True, 
        hue=target, 
        x=col
    )
    # Добавляем поворот подписей
    plt.xticks(rotation=rotation_angle, ha='right')  
    plot.set_title(f'Распределение по {col}', fontsize=16)
    plot.set_ylabel('Количество', fontsize=14)
    plot.set_xlabel(col, fontsize=14)  
    plt.tight_layout()  
    plt.show()
    
    
def categoral_unique(df, col):
    display(df[col].unique())
    
    plt.figure(figsize=(8,6))
    plot = sns.countplot(y=col, data=df)
    plot.set_title(f'Рапределение по {col}', fontsize=16)
    plot.set_xlabel('Количество', fontsize=14)

# %%
cat_columns = list(segment_data.select_dtypes(include='object').columns)
di_columns = numeric_columns
num_columns = ['маркет_актив_6_мес', 'длительность', 'акционные_покупки', 'прибыль']

# %%
for name in num_columns:
    plt.figure(figsize=(10, 4))
    plt.title(f'Признак "{name}"')
    plt.xlabel('Вероятность принадлежности к снижнению активности')
    plt.ylabel(f'Значение')
    plt.scatter(x=segment_data['вероятность'], 
                y=segment_data[name],
                alpha=0.5)

# %% [markdown]
# Показательнее всего разделяются покупатели которые покупают по акции и нет. Вероятнее всего на этом примере лучше всего и провести их сегментацию

# %% [markdown]
# С этой целью разделим покупателей на 2 категории `черри_пикеры` со значенеми акционные покупки >0.6  и `традиционные_покупатели` со значением < 0.6

# %% [markdown]
# `средний_просмотр_категорий_за_визит` согласно модели являестя важным показателем для анализа попробуем поделить их на 3 категории `заинтересованые` 5-6 `интересующиеся` 3-4 и `скучающие` 1-2

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отличный выбор

# %%
segment_data['акционные_покупки_категория'] = segment_data['акционные_покупки']\
.apply( lambda x: 'черри_пикеры' if x>= 0.6 else 'традиционные_покупатели' )

# %%
segment_data['заинтересованность_категория'] = segment_data['средний_просмотр_категорий_за_визит'].apply(lambda x: 
    'заинтересованные' if 5 <= x <= 6 else
    'интересующиеся' if 3 <= x <= 4 else
    'скучающие' if 1 <= x <= 2 else
    'неопределенная категория'
)

# %%
display(segment_data['заинтересованность_категория'].value_counts())

# %%
# Группируем данные по категориям заинтересованности и считаем среднюю вероятность принадлежности
profit_analysis = segment_data.groupby('заинтересованность_категория')['вероятность'].agg(['mean', 'median', 'count'])

# Выводим результаты группировки
print("Анализ прибыли по категориям заинтересованности:")
print(profit_analysis)

# Визуализация результатов
plt.figure(figsize=(12, 6))

# График 1: Средняя прибыль по категориям
plt.subplot(1, 2, 1)
sns.barplot(
    x='заинтересованность_категория',
    y='вероятность',
    data=segment_data,
    estimator=np.mean,
    ci=95
)
plt.title('Средняя вероятность по категориям заинтересованности')
plt.xlabel('Категория заинтересованности')
plt.ylabel('Средняя вероятность')

# График 2: Ящик с усами
plt.subplot(1, 2, 2)
sns.boxplot(
    x='заинтересованность_категория',
    y='вероятность',
    data=segment_data,
    showmeans=True
)
plt.title('Распределение вероятности принадлежности к классу снижения активности  по категориям')
plt.xlabel('Категория заинтересованности')
plt.ylabel('вероятность')

plt.tight_layout()
plt.show()

# %% [markdown]
# На данном этапе можно предположить что скучающие с высокой долей вероятности могут уйти в снижение активности.Однако надо обратить внимание на сильную разбалансировку заинтересованных занчительно меньше .Попробуем другой метод оценки групп

# %%
# Альтернативный способ анализа связи
# Можно использовать ANOVA тест для проверки значимости различий
from scipy.stats import f_oneway

# Разделяем данные по категориям
group1 = segment_data[segment_data['заинтересованность_категория'] == 'заинтересованные']['вероятность']
group2 = segment_data[segment_data['заинтересованность_категория'] == 'интересующиеся']['вероятность']
group3 = segment_data[segment_data['заинтересованность_категория'] == 'скучающие']['вероятность']

# Проводим ANOVA тест
f_stat, p_value = f_oneway(group1, group2, group3)
print(f"\nANOVA тест: F-статистика = {f_stat}, p-значение = {p_value}")

if p_value < 0.05:
    print("Существует статистически значимая разница между группами")
else:
    print("Нет статистически значимой разницы между группами")

# %% [markdown]
# Вероятно исходя из текущих данных мы можем предположить что существует статистически значимая разница в средних значениях вероятности снижения покупательской активности между тремя группами
#
# Группы действительно различаются по этому показателю. А следовательно данная тактика сегментации имеет смысл
#
# Необходимо :
# - разрабатывать разные стратегии работы с каждой группой
# - учитывать эти различия при планировании маркетинговых кампаний
# - сформировать особый подход к каждой категории клиентов

# %% [markdown]
# Следующим шагом рассмотрим вторую гипотезу о черри-пикерах

# %%
# Анализ статистики по акционным покупкам
profit_analysis_promo = segment_data.groupby('акционные_покупки_категория')['вероятность'].agg(
    средняя_вероятность='mean',
    медиана='median',
    количество_наблюдений='count',
    std_dev='std'
)

print("Анализ вероятности по категориям акционных покупок:")
print(profit_analysis_promo)

# Визуализация
plt.figure(figsize=(14, 7))

# График 1: Средняя прибыль
plt.subplot(1, 2, 1)
sns.barplot(
    x='акционные_покупки_категория',
    y='вероятность',
    data=segment_data,
    estimator=np.mean,
    ci=95
)
plt.title('Средняя вероятность по категориям акционных покупок')
plt.xlabel('Категория акционных покупок')
plt.ylabel('Средняя вероятность')

# График 2: Боксплот
plt.subplot(1, 2, 2)
sns.boxplot(
    x='акционные_покупки_категория',
    y='вероятность',
    data=segment_data,
    showmeans=True
)
plt.title('Распределение вероятность по категориям акционных покупок')
plt.xlabel('Категория акционных покупок')
plt.ylabel('вероятность')

plt.tight_layout()
plt.show()

# Статистический анализ
# фильтруем данные
group_promo1 = segment_data[segment_data['акционные_покупки_категория'] == 'черри_пикеры']['вероятность']
group_promo2 = segment_data[segment_data['акционные_покупки_категория'] == 'традиционные_покупатели']['вероятность']


# Проводим ANOVA тест
f_stat_promo, p_value_promo = f_oneway(group_promo1, group_promo2)
print(f"\nANOVA тест для акционных покупок: F-статистика = {f_stat_promo}, p-значение = {p_value_promo}")

if p_value_promo < 0.05:
    print("Существует статистически значимая разница между группами по акционным покупкам")
else:
    print("Нет статистически значимой разницы между группами по акционным покупкам")

# %% [markdown]
# исходя из полученных результатов можно так же сделать ряд выводов:
#
# - Черри-пикеры более склонны к снижению активности
#
# - Традиционные покупатели демонстрируют более стабильное поведение
#
# Что в целом достаточно закономерно черри пиккеры веротяно шерстят много разных сайтов в поисках самых лучших предложений.
#
# Вероятно следуте разработать отдельные стратегии удержания для каждой группы например:
#
# - Для черри-пикеров:
#
#   - Специальные программы лояльности
#
# - Для традиционных покупателей:
#
#   - Поддержание стабильного взаимодействия
#
#   - Регулярные предложения
#
# Необходимо обратить внимание размер выборки для черри-пикеров меньше, но  почему то статистическая значимость сохраняется.
# Высокая дисперсия у традиционных покупателей может указывать на неоднородность группы.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# На правах мнения:
#
# Повторюсь, меня здесь смущает, что у нас не нормальное распределение по доле акционных покупок. Если бы это был просто параметр, который зависит от предпочтений людей (кто-то любит акции больше, кто-то на них не обращает внимание), то параметр был бы распределен нормально. Однако у нас две модальности. Это намекает на то, что сервис каким-то образом предоставил специальные акциии именно этой группе пользователей и дальше все их покупки до какого-то времени записывались в акционные.
#
# Тогда снижение может быть связано с тем, что акция завершилась и магазин стал не таким выгодным. Возможно, это нормальная реакция покупателей на ухудшение условий для покупок.
#
# ***
#
# Твоя гипотеза тоже может иметь место, да и к моей версии могут быть вопросы.

# %% [markdown]
# Расмотрим другие взаимотношения по группам

# %%
histogram(segment_data,'страниц_за_визит','акционные_покупки_категория')

# %% [markdown]
# Здесь сохранется прежняя законемерность черри-пикер точно знает зачем пришел и сайт не разглядывает пришел увидел победил (купил)

# %%
histogram(segment_data, 'маркет_актив_тек_мес', 'акционные_покупки_категория')

# %%
histogram(segment_data, 'неоплаченные_продукты_штук_квартал', 'акционные_покупки_категория')

# %% [markdown]
# В целом по обоим графикам сходная тенденция активность у черри-пикеров не высокая как и количество не оплаченных покупок.
#
# ОДНАКО результаты  данного анализа может легко обьяснться значимой разницой в размерах групп.

# %%
histogram(segment_data,'маркет_актив_тек_мес','заинтересованность_категория')

# %% [markdown]
# 3-4 страниц для покупки вполне достаточно а вот слишком долго сидеть смысло мало 5-6 страниц а активность ниже видимо этио говрит что заинтересованные сами не знают что хотят может стоит лучше настраивать таргетную рекламу?

# %%
histogram(segment_data, 'неоплаченные_продукты_штук_квартал', 'заинтересованность_категория')

# %% [markdown]
# Скучающие в итоге больше оставляют неопалченных покупок вероятно просто неуспевают решиться на покупку?!

# %%
categoral_unique(segment_data, 'популярная_категория')

# %% [markdown]
# Самой популярной стала категория товары для детей что в целом логично ) вопрос заказа игрушки для ребенка подешевле из интернета будет всегда актуален

# %%
histogram(segment_data, 'популярная_категория', 'заинтересованность_категория',rotation_angle=20)

# %% [markdown]
# Категории «косметика и аксессуары» и «кухонная посуда» имеют наибольшую долю заинтересованных пользователей.
#
# Категории «домашний текстиль» и «товары для детей» показывают равномерное распределение между заинтересованными и интересующимися.
#
# Категория «техника для красоты и здоровья» имеет заметную долю скучающих пользователей

# %%
histogram(segment_data, 'популярная_категория', 'акционные_покупки_категория',rotation_angle=20)

# %% [markdown]
# Акционные покупки наиболее активны в категориях мелкой бытовой техники и электроники.
#
# Традиционные покупатели предпочитают домашний текстиль и товары для детей.
#
# Черри-пикеры проявляют минимальную активность во всех категориях что скорее обьяснется их значительно меньшим количеством и
# данный вывод не очень информативен

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Обязательно стоит изучить, а какие категории товаров популярны вообще и популярны конкретно у нашей группы.

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# Выше добавил визуализацию с выводами по категориям товаров

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Для наглядности хорошо бы нормализовать гистограммы. Кажется, это можно проще всего сделать параметром common_norm=False, если используем hue для выведения разных гистограмм на одном графике.

# %% [markdown]
# ### Общие выводы

# %% [markdown]
# **Загрузка данных**

# %% [markdown]
# Исходными данными для исследования были четыре отдельных csv файла.Данные загруженны в полном обьеме,соответствуют заявленному ТЗ.В дальнешем называются `market_f`,`market_m`, `market_t`  и `money` соответственно.

# %% [markdown]
# **Предобработка данных**

# %% [markdown]
# в `market_f`
#
# - исправелены названия стоблцов и обнаружены  неявные дубликаты в Тип сервиса 'стандартт' 'стандарт'
#
# в `market_m`
#
# - исправелны названия стоблцов и термин препредыдущий_месяц
#
# в `market_t`
#
# - исправелны названия стоблцов и термин предыдцщий
#
# в `money`
#
# - исправлены названия стоблцов

# %% [markdown]
# **Исследовательский анализ данных**

# %% [markdown]
# **выводы по `market_f`** :
#
# Показатель `маркет_актив_6_мес` отмечаются выбивающиеся значения около нулевых значений. Для наибольшего количества покупателей составляет 4.2. Распределение стремится к нормальному.
#
# Показатель `маркет_актив_тек_мес`, `Средний просмотр за категорий за визит` ,`Неоплаченные продукты`, `Ошибка сервиса`  дискретны.
#
# Гистограмма анализа `страниц за визит` наиболее стремится к нормальному распределению по сравнению с остальными графиками выбросов не отмечено.
#
# Показатель `Покупательская активность` представлен 2 значениями прежний уровень и снизилась значение снизилась почти в 2 ое меньше прежнего уровня.
#
# По `типам сервиса` клиенты распределены не равномерно стандартных клиентов значительно больше
#
# Так же большинство клиентов предоставили свою данные для обработки.
#
# Самой популярной категорией среди товаров стали товары для детей.
#
# **выводы по анализу `market_m`** :
#
# Удален выброс единственное значение в 106862. Так же удалены клиенты не принесших выручки для предстоящего моделирования они не отвечают заданным требованиям. Сразу же эти клиенты удалены из остальных предоставленных дата сетов во избежание дальнейших ошибок. Данные представлены гистограммой образующий правильный купол нормального распределения.
#
# **Выводы по анализу `market_t`** :
#
# Данные представлены почти правильны куполом нормального распределения однако с 2 мя пиками около 12 и 15 минутам. Среднее значение составило 13.3.
#
# **Выводы по анализу `money`**  : Данные представлены почти правильны куполом нормального распределения 1 пиком около 4 пунктов. Среднее значение составило 4.04.

# %% [markdown]
# **Корреляционный анализ данных**

# %% [markdown]
# На основании проведенного анализа выявлены следующие статистические зависимости:
#
# Сильная корреляционная связь установлена между следующими показателями:
#
# Значения выручки за месяц до предыдущего демонстрируют высокую степень зависимости от показателей выручки за предыдущий месяц
#
# Существует значимая корреляция между покупатльской активностью и кол-вом страниц за визит а так же время за предыдущий месяц

# %% [markdown]
# **Объеденение таблиц**

# %% [markdown]
# Таблицы успешно обьединены по ID клиента

# %% [markdown]
# **Обучение модели**

# %% [markdown]
# В рамках поставленной задачи подобрана модель для прогнозирования метрика ROC-AUC на тестовой выборке составило 0.92
#
# Метрика на тренировочной выборке: 0.89 с помощью RandomizedSearchCV осуществлен подбор оптимальных гиперпараметров и модели

# %% [markdown]
# **Анализ важности признаков**

# %% [markdown]
# Согласно плану методом SHAP (SHapley Additive exPlanations) выполнена оценка вклада признака. В ТОП 3 лучших вошли следуюющие параметры `средний_просмотр_категорий_за _визит` , `страниц_за_визит`, `время_предыдущий месяц`.
# а вот самыми худшими признаками стали `популярная_категория_товары_для детей`,`популярная_категрия_кухонная_посуда`,`популярная_категория`.
#
# Весьма вероятно что время проведенное на сайте оказывает значительное влияиние на покупательскую активность, хотя стоит помнить что тот кто собствено покупает что либо будет задерживаться на сайте дольше(оформлять заказ заполняить данные о карте и тд и тп) чем следует на принятие решения о покупке.Возможно данный топ 3 на самом деле своего рода засветкой данных..Необходимо уточнить у зазчика особенности сбора данных.

# %% [markdown]
# **Сегментация пользователей**

# %% [markdown]
# в рамках сегментации было выделено две группы первая  разделила  покупателей на тех  которые покупают по акции и нет.
#
# С этой целью разделим покупателей на 2 категории черри_пикеры со значенеми акционные покупки >0.6 и традиционные_покупатели со значением < 0.6
#
# Вторая группа опредлена показателем средний_просмотр_категорий_за_визит котрый  согласно модели являестя важным показателем для анализа попробуем поделить их на 3 категории заинтересованые 5-6 интересующиеся 3-4 и скучающие 1-2(вероятно стоит подобрать лучшие термины)

# %% [markdown]
# По первой группе исходя из полученных результатов можно сделать ряд выводов:
#
# - Черри-пикеры более склонны к снижению активности
#
# - Традиционные покупатели демонстрируют более стабильное поведение
#
# Что в целом достаточно закономерно черри пиккеры веротяно шерстят много разных сайтов в поисках самых лучших предложений.
#
# Вероятно следуте разработать отдельные стратегии удержания для каждой группы например:
#
# - Для черри-пикеров:
#
#   - Специальные программы лояльности
# - Для традиционных покупателей:
#
#   - Поддержание стабильного взаимодействия
#
#   - Регулярные предложения
#
# Необходимо обратить внимание размер выборки для черри-пикеров меньше, но почему то статистическая значимость сохраняется. Высокая дисперсия у традиционных покупателей может указывать на неоднородность группы.Рекомендую более детальный анализ данной группы и набор большего количества данных по этой групппе

# %% [markdown]
# По второй группе исходя из текущих данных мы можем предположить что существует статистически значимая разница в средних значениях вероятности снижения покупательской активности между тремя группами
#
# Группы действительно различаются по этому показателю. А следовательно данная тактика сегментации имеет смысл
# учитывая это для улучшения показателей необходимо :
#
# - разрабатывать разные стратегии работы с каждой группой
# - учитывать эти различия при планировании маркетинговых кампаний
# - сформировать особый подход к каждой категории клиентов
# - провести подробный анализ этих групп

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Здесь покритикую твои выводы.
#
# Заказчик хочет получить от нас что-то конкретное, что будет увеличивать его выручку ну или делать сервис более привлекательным для клиентов.
#
# Твои рекомендации пока слишком абстрактные, мы могли бы их дать и без выполнения проекта. Если до проекта и после проекта мы могли бы дать одинаковые рекомендации, тогда в чем польза от нашей работы?
#
# Ну да, мы заранее предполагали, что наши клиенты могут быть разделены на сегменты. Да, логично предположить, что для каждого сегмента будет полезен свой подход. Да, это стоит учитывать при планировании маркетинговых кампаний, и да, хорошо бы проанализировать эти группы.
#
# Вот как раз наша задача − проанализировать данные, выброать группу и понять, как конркетно эффективнее всего удерживать активность группы.

# %% [markdown]
# <br/>
# <div class="alert alert-info">
#
# Ниже постарался конкретизировать.

# %% [markdown]
#
# Основные проблемы снижающих активность:
# - Меньше проводят времени на сайте и смотрят меньше страниц.
# - Чаще покупают только по акциям.
# - Меньше тратят за визит.
# - Сосредоточены на узком наборе категорий.
# - Чаще сталкиваются с ошибками сервиса.
# - Меньше вовлечены в коммуникации (не хотят получать сообщения).
#
#  Рекомендации по удержанию:
#  1. Персонализированные акции
#  - Делать целевые скидки именно на  любимые категории (бытовая техника электороника,косметика,кухонная посуда ).
#  - Показывать выгодные наборы (например, «купи 2, получи 3-й со скидкой»).
#  - Сегментировать акции (по выделенным группам).
#  2. Увеличение вовлеченности (увелить время нахождения на сайте)
#  - Предлагать подборки «Похожие товары», чтобы увеличить число просмотренных страниц.
#  - Добавить «рекомендации дня» или «что покупают вместе с этим».
#  - Геймификация: накопительные бонусы за просмотр новых категорий или продуктов.
#  3. Снижение  ошибок
#  - ~Минимизировать количество ошибок и зависаний — у этой группы они критичнее влияют на лояльность~.
#  - Минимизировать количество ошибок и зависаний  несмотря на минимальное их влияние на лояльность
#  4. Разнообразие ассортимента
#  - Мягко предлагать новые категории через кросс-селл («Вам может понравиться»).
#  - давать бонус за первую покупку в новой категории.
#  5. Коммуникация
#  - Так как они часто отказываются от сообщений — стоит использовать мягкие уведомления внутри сайта/приложения вместо навязчивых рассылок.
#  6. Программы удержания
#  - Запускать акции «Вернись за скидкой» для тех, кто не покупал определённое время.
#  - Давать бонусы за регулярность, чтобы стимулировать возвращение.
#  - «премиум» аккаунты не повышают лояльность необходимо оптимизировать бонусы для 'премиумов'.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Cовсем другое дело. Отлично, что обращаешь внимание на коммуникацию.
#
# По количеству ошибок, я бы не сказал, что различия и по таргету ,и по нашему сегменту будут значимыми. Кажется, ошибки все-таки не являются проблемой, влияющей на уход клиентов.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Эта работа также была достаточно объемной и требовала концентрации внимания. По структуре проекта, логичности действий и общему подходу все замечательно.
#
# **Отмечу положительные моменты проекта🚀**
#
# * Хорошие решения в коде, есть пояснения и аргументации.
# * Грамотная предобработка и подготовка признаков.
# * Корректное обучение моделей, использование пайплайнов.
#
#
# **На что стоит обратить внимание🤔**
#
# * Важно в исследовательском анализе рассмотреть отдельно подвыборки для клиентов со снижающейся и с постоянной активностью (делим по целевому признаку).
# * Необходимо обосновать выбор метрики качества.
# * Рекомендую также углубить и исследование сегмента: там, где можем, смотрим на динамику в категориях товаров.
# * Важно дать основанные на данных и исследовании рекомендации заказчику.
# * Эти и остальные замечания я также написал по ходу проекта.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
#
#
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
#
# Большое спасибо за Ваш работу и проведенный анализ. У меня остается один волнующий меня вопрос ? обе группы для сегментации имеют значимую разницу в численном составе.Насколько это вообще целесообразно их сравнивать ? так называемые черри пикеры это 44 человека к 281 обычному.На первый взгляд звучит как абослютно несопоставимо

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Слушай, отличный вопрос. Второе замечание критичнее. Я прошу прощения, что пропустил этот момент при проверке. Хорошо бы нам взять в группу для анализа хотя бы 100 человек. Это можно сделать, если выше взять не тестовую выборку, а вообще все данные.
#
# Смотри, мы построили модель, протестировали, поняли, что она работает. Ок. Теперь мы можем использовать ее для того, чтобы во всей таблице из 1296 строк перевести значения в вероятности классов. Берем модель, переводим. Дальше уже у нас будет больше маневра, чтобы выделить статистически значимый сегмент.
#
# По первому − выше советую нормализовать отображение в гистограммах. Есть множество вариантов, как это сделать. common_norm=False - самый простой. Нам интересно сравнивать распределения, а сколько данных в каждом из них при условии, что минимально достаточно, − не важно.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Комментарий ко второй проверке**
#
# Спасибо за качественную доработку. Практически все верно. Однако еще кое-что осталось.
#
# Отличное замечание про размер сегмента. Этот момент критичный, я его пропустил. Давай поправим: рассчитаем вероятности классов для всех данных.
#
# Сравнивать нормализованные распределения будет и просто, и полностью верно. Сравнивать ненормализованные визуально сложнее, но тоже можно, проблем с этим нет. Вообще же основные сравнения у нас будут на этапе исследовательского анализа. В сегменте мы просто изучаем характеристики выбранного сегмента, здесь уже сравнения для хороших выводов необязательны, хотя они никогда не помешают, здесь нам важно просто изучить предпочтения и особенности.
#
# Выше обрати внимание по выводам, что ошибки на сайте все-таки минимально влияют на активность. Как и «премиум» аккаунты не повышают лояльность − что можем отметить как недоработку.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
#
# Внес исправления в общие выводы.
#
# Так же уже 10 пунктом расширил наше с вами исследование.(надеюсь я правильно и в полном обьеме  понял ваши замечания и указания)

# %% [markdown]
# ### Дополнительный анализ сверх задания

# %%
# Получаем лучшие параметры модели
best_model = randomized_search.best_estimator_

# Получаем вероятности для тестового набора данных
# Метод predict_proba возвращает вероятности для каждого класса
# Берем вероятность положительного класса (обычно второй столбец)
market['вероятность'] = best_model.predict_proba(market.drop('покупательская_активность', axis=1))[:, 1]


# Проверка результатов
print(market[['покупательская_активность', 'вероятность']].head())

# %%
market.head()

# %% [markdown]
# Расширили нашу базу засчет основного датасета применив к нему нашу лучшую модель

# %%
market['акционные_покупки_категория'] = market['акционные_покупки']\
.apply( lambda x: 'черри_пикеры' if x>= 0.6 else 'традиционные_покупатели' )

# %% [markdown]
# По скольку численная разница оказалась самой большой в варианте сегментации с черри пикерами взял для дальнейшей разработки его

# %%
display(market['акционные_покупки_категория'].value_counts())

# %% [markdown]
# чтож на общем датасете пропорции оказались теже что и в маленьком варианте

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #3 <a class="tocSkip"> </h2>
#
# 👍 Привет. Наверное, можно было сразу выше дополнить данные.
# </div>

# %%
# Анализ статистики по акционным покупкам
profit_analysis = market.groupby('акционные_покупки_категория')['вероятность'].agg(
    средняя_вероятность='mean',
    медиана='median',
    количество_наблюдений='count',
    std_dev='std'
)

print("Анализ вероятности по категориям акционных покупок:")
print(profit_analysis)

# Визуализация
plt.figure(figsize=(14, 7))

# График 1: Средняя прибыль
plt.subplot(1, 2, 1)
sns.barplot(
    x='акционные_покупки_категория',
    y='вероятность',
    data=market,
    estimator=np.mean,
    ci=95
)
plt.title('Средняя вероятность по категориям акционных покупок')
plt.xlabel('Категория акционных покупок')
plt.ylabel('Средняя вероятность')

# График 2: Боксплот
plt.subplot(1, 2, 2)
sns.boxplot(
    x='акционные_покупки_категория',
    y='вероятность',
    data=market,
    showmeans=True
)
plt.title('Распределение вероятность по категориям акционных покупок')
plt.xlabel('Категория акционных покупок')
plt.ylabel('вероятность')

plt.tight_layout()
plt.show()

# Статистический анализ
# фильтруем данные
group_promo1 = market[market['акционные_покупки_категория'] == 'черри_пикеры']['вероятность']
group_promo2 = market[market['акционные_покупки_категория'] == 'традиционные_покупатели']['вероятность']


# Проводим ANOVA тест
f_stat_promo, p_value_promo = f_oneway(group_promo1, group_promo2)
print(f"\nANOVA тест для акционных покупок: F-статистика = {f_stat_promo}, p-значение = {p_value_promo}")

if p_value_promo < 0.05:
    print("Существует статистически значимая разница между группами по акционным покупкам")
else:
    print("Нет статистически значимой разницы между группами по акционным покупкам")

# %% [markdown]
# Для использования нормализации в гистограммах  переделал функцию (а чтобы разобраться в разнице для сравнения применил и старую версию и новую)

# %%
def histogram_norm(df, col, target, rotation_angle=45):
    plt.figure(figsize=(8,6))
    
    # Добавляем параметр stat='probability' для нормализации
    plot = sns.histplot(
        df, 
        bins=20, 
        kde=True, 
        hue=target, 
        x=col,
        stat='probability',  # Нормализация по вероятности
        common_norm=False    # Отключаем общую нормализацию
    )
    
    # Добавляем поворот подписей
    plt.xticks(rotation=rotation_angle, ha='right')  
    
    # Настройка заголовков и подписей
    plot.set_title(f'Распределение по {col}', fontsize=16)
    plot.set_ylabel('Нормализованная вероятность', fontsize=14)  # Изменили подпись оси Y
    plot.set_xlabel(col, fontsize=14)  
    
    plt.tight_layout()  
    plt.show()

# %%
histogram(market, 'маркет_актив_тек_мес', 'акционные_покупки_категория')

# %%
histogram_norm(market, 'маркет_актив_тек_мес', 'акционные_покупки_категория')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 вот здесь похоже на то, что нам нужно с нормализацией.
# </div>

# %%
histogram(market,'страниц_за_визит','акционные_покупки_категория')

# %%
histogram_norm(market,'страниц_за_визит','акционные_покупки_категория')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Тут в сравнении видно, что можем анализировать данные в обоих вариантах, но нормализованный явно удобнее.
# </div>

# %%
histogram(market, 'неоплаченные_продукты_штук_квартал', 'акционные_покупки_категория')

# %%
histogram_norm(market, 'неоплаченные_продукты_штук_квартал', 'акционные_покупки_категория')

# %% [markdown]
# **Подводя итоги**
#
# Несмотря на расширение  анализируемого датасета общая тенденция не изменилась. Подход получается тот же. Необходимсти в измении выводов нет.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Ок. Но теперь мы уверены, что наши данные не случайно так сложились из-за недостаточной выборки.
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Комментарий к финальной проверке**
#
# Спасибо за уточнение и дополнение по проекту.
#
# Если что-то пропустил или остались вопросы, напиши в телеграм @kriill
#
# Желаю удачи в дальнейшей учебе!
#
# </div>
